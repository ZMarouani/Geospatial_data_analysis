# %%
aws_bucket_name = "train-data-20221903"
mount_name = "s3-bucket-mount"
dbutils.fs.mount("s3a://%s" % aws_bucket_name, "/mnt/%s" % mount_name)
display(dbutils.fs.ls("/mnt/%s" % mount_name))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/mnt/s3-bucket-mount/oregon-prod/</td><td>oregon-prod/</td><td>0</td></tr><tr><td>dbfs:/mnt/s3-bucket-mount/sample_data/</td><td>sample_data/</td><td>0</td></tr></tbody></table></div>

# %%
# dbutils.fs.unmount(f"/mnt/{mount_name}")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/mnt/s3-bucket-mount has been unmounted.
# Out[6]: True</div>

# %%
dbutils.fs.ls("s3a://train-data-20221903/train_data/affinities/affinities/")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[4]: [FileInfo(path=&#39;s3a://train-data-20221903/train_data/affinities/affinities/addidas.gz&#39;, name=&#39;addidas.gz&#39;, size=37428),
#  FileInfo(path=&#39;s3a://train-data-20221903/train_data/affinities/affinities/apple.gz&#39;, name=&#39;apple.gz&#39;, size=65085),
#  FileInfo(path=&#39;s3a://train-data-20221903/train_data/affinities/affinities/bmw.gz&#39;, name=&#39;bmw.gz&#39;, size=53914),
#  FileInfo(path=&#39;s3a://train-data-20221903/train_data/affinities/affinities/employed.gz&#39;, name=&#39;employed.gz&#39;, size=47459),
#  FileInfo(path=&#39;s3a://train-data-20221903/train_data/affinities/affinities/female.gz&#39;, name=&#39;female.gz&#39;, size=530831),
#  FileInfo(path=&#39;s3a://train-data-20221903/train_data/affinities/affinities/h_&amp;_m.gz&#39;, name=&#39;h_&amp;_m.gz&#39;, size=39932),
#  FileInfo(path=&#39;s3a://train-data-20221903/train_data/affinities/affinities/high_income.gz&#39;, name=&#39;high_income.gz&#39;, size=105295),
#  FileInfo(path=&#39;s3a://train-data-20221903/train_data/affinities/affinities/honda.gz&#39;, name=&#39;honda.gz&#39;, size=80822),
#  FileInfo(path=&#39;s3a://train-data-20221903/train_data/affinities/affinities/job_seeking.gz&#39;, name=&#39;job_seeking.gz&#39;, size=54942),
#  FileInfo(path=&#39;s3a://train-data-20221903/train_data/affinities/affinities/low_income.gz&#39;, name=&#39;low_income.gz&#39;, size=190933),
#  FileInfo(path=&#39;s3a://train-data-20221903/train_data/affinities/affinities/male.gz&#39;, name=&#39;male.gz&#39;, size=472982),
#  FileInfo(path=&#39;s3a://train-data-20221903/train_data/affinities/affinities/mercedes-benz.gz&#39;, name=&#39;mercedes-benz.gz&#39;, size=57653),
#  FileInfo(path=&#39;s3a://train-data-20221903/train_data/affinities/affinities/middle_income.gz&#39;, name=&#39;middle_income.gz&#39;, size=614514),
#  FileInfo(path=&#39;s3a://train-data-20221903/train_data/affinities/affinities/retired.gz&#39;, name=&#39;retired.gz&#39;, size=31953),
#  FileInfo(path=&#39;s3a://train-data-20221903/train_data/affinities/affinities/student.gz&#39;, name=&#39;student.gz&#39;, size=71986),
#  FileInfo(path=&#39;s3a://train-data-20221903/train_data/affinities/affinities/tommy_helfinger.gz&#39;, name=&#39;tommy_helfinger.gz&#39;, size=33552)]</div>

# %%
dbutils.fs.ls("dbfs:/mnt/s3-bucket-mount/train_data/stores.csv")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[6]: [FileInfo(path=&#39;dbfs:/mnt/s3-bucket-mount/train_data/stores.csv&#39;, name=&#39;stores.csv&#39;, size=125651)]</div>
